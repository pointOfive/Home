# %% [markdown]
# # $$\text{NLP: Natural Language Processing}$$
#
#
# # OBJECTIVES:
# # 1. Tokens/Bag of Words
# # 2. Text Normalization: stemming/lemmatizing, stop words, punctuation/whitespace
# # 3. TF-IDF
# # 4. Cosine Similarity
#
# <br>
#
# ## BONUS (https://www.youtube.com/watch?v=6zm9NC9uRkk):
# ## 1. spacy
# ## $\quad$ a. Entity Identification
# ## $\quad$ b. Part of Speech Tagging
# ## $\quad$ c. Text "Normalization"
# ## 2. gensim
# ## $\quad$ a. Phrase Modeling
# ## $\quad$ b. Topic Modeling
# ## $\quad$ c. Word2Vec
# ## 3. textacy

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.nyt_dump
coll = db.articles

# %%
def unicodetoascii(text):# \xe2\x80\x9c#replace(u'\xe2\xad',"").
    TEXT = text.replace(u'\xe2\x80\x99', "'").replace(u'\xc3\xa9', 'e').replace(u'\xe2\x80\x90', '-').replace(u'\xe2\x80\x91', '-').replace(u'\xe2\x80\x92', '-').replace(u'\xe2\x80\x93', '-').replace(u'\xe2\x80\x94', '-').replace(u'\xe2\x80\x94', '-').replace(u'\xe2\x80\x98', "'").replace(u'\xe2\x80\x9b', "'").replace(u'\xe2\x80\x9c', '"').replace(u'\xe2\x80\x9c', '"').replace(u'\xe2\x80\x9d', '"').replace(u'\xe2\x80\x9e', '"').replace(u'\xe2\x80\x9f', '"').replace(u'\xe2\x80\xa6', '...').replace(u'\xe2\x80\xb2', "'").replace(u'\xe2\x80\xb3', "'").replace(u'\xe2\x80\xb4', "'").replace(u'\xe2\x80\xb5', "'").replace(u'\xe2\x80\xb6', "'").replace(u'\xe2\x80\xb7', "'").replace(u'\xe2\x81\xba', "+").replace(u'\xe2\x81\xbb', "-").replace(u'\xe2\x81\xbc', "=").replace(u'\xe2\x81\xbd', "(").replace(u'\xe2\x81\xbe', ")")
    return TEXT

# %%
documents = [unicodetoascii(' '.join(article['content']).lower()) for article in coll.find()]

# %%
documents = [d for d in documents if len(d) > 0]

# %%
len(documents)
# Out:
# 984

# %%
print len(documents)
documents[2]
# Out:
# 984
# u'\n\n\n\n\n\n\n\n\n\n\n\'shining\' star: "doctor sleep," stephen king\'s much-\xe2\xadanticipated sequel to "the shining," isn\'t on the hardcover list yet - its official release date is sept. 24 - but back in 1977, "the shining" did spend time there on its way to becoming a cultural touchstone. (it also sold well in paperback, especially after stanley kubrick\'s 1980 film adaptation.)        \n \n\n"the shining" was king\'s third novel, and both the book review and the daily new york times paid attention, though king might have wished they hadn\'t: "to say that stephen king is not an elegant writer," jack sullivan groused in the book review, "is putting it mildly." the daily\'s reviewer, richard r. lingeman, wasn\'t much kinder: "the evil is slapdash, unfocused and eventually preposterous," he wrote. "king is a natural, but he lacks control; he simply rears back and lets fly with the fireball, and a lot of wild pitches result." the criticism apparently stung. "sales aren\'t all-important," king later told lingeman. "we all want to be nominated for a national book award." i grew up reading king, and the literary establishment has gradually come around; in 2003, the national book foundation awarded him a medal for distinguished contribution to american letters.        \nthe ballad of jail reading: in next week\'s issue, lauren groff will review peter orner\'s new story collection, "last car over the sagamore bridge." orner has never hit the best-seller list, despite critical acclaim, but he did have a recent brush with the wilder side of popular fiction - as the expert witness in a lawsuit involving a california prisoner\'s right to read werewolf erotica. (the plaintiff, an inmate at pelican bay state prison, successfully appealed after his copy of mathilde madden\'s "silver crown" was confiscated.)        \n"at stake in the case was the very tricky and very subjective issue of literary value," orner told me via e-mail. "as a fiction writer, you can\'t really say no when someone asks you to read some werewolf erotica, especially for a good cause. and i\'d say the right to read, wherever you are, is a pretty good cause." orner ended up "tearing through" the book, he said. "i tend to be a very slow reader. i read \'the silver crown\' fast - the prose really moves, let\'s say. i wish i had as much action in my own books."        \norner studied law, and has worked in prisons both in a legal capacity and as a writing teacher. he\'s sympathetic, he told me, to their challenges. but he would tend to allow most books. "correctional officers have to enforce discipline in an incredibly tough environment," he said. "pelican bay is one of the most violent prisons in california. . . . they\'ve got some extraordinarily serious problems. my humble thought, speaking as a writer, is that an inmate reading a book about werewolves having sex is the least of their problems."        \n\n\n\n \n\n\n\n'

# %%
# conda install nltk
# sudo pip install -U nltk
# windows is just: "import nltk"?

import nltk
#nltk.download('book')
#nltk.download('punkt')

# %%
tokenized_docs = []
for document in documents:
    tokenized_docs.append(nltk.word_tokenize(document))

# %%
tokenized_docs[2]
# Out:
# [u"'shining",
#  u"'",
#  u'star',
#  u':',
#  u'``',
#  u'doctor',
#  u'sleep',
#  u',',
#  u"''",
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticipated',
#  u'sequel',
#  u'to',
#  u'``',
#  u'the',
#  u'shining',
#  u',',
#  u"''",
#  u'is',
#  u"n't",
#  u'on',
#  u'the',
#  u'hardcover',
#  u'list',
#  u'yet',
#  u'-',
#  u'its',
#  u'official',
#  u'release',
#  u'date',
#  u'is',
#  u'sept.',
#  u'24',
#  u'-',
#  u'but',
#  u'back',
#  u'in',
#  u'1977',
#  u',',
#  u'``',
#  u'the',
#  u'shining',
#  u"''",
#  u'did',
#  u'spend',
#  u'time',
#  u'there',
#  u'on',
#  u'its',
#  u'way',
#  u'to',
#  u'becoming',
#  u'a',
#  u'cultural',
#  u'touchstone',
#  u'.',
#  u'(',
#  u'it',
#  u'also',
#  u'sold',
#  u'well',
#  u'in',
#  u'paperback',
#  u',',
#  u'especially',
#  u'after',
#  u'stanley',
#  u'kubrick',
#  u"'s",
#  u'1980',
#  u'film',
#  u'adaptation',
#  u'.',
#  u')',
#  u'``',
#  u'the',
#  u'shining',
#  u"''",
#  u'was',
#  u'king',
#  u"'s",
#  u'third',
#  u'novel',
#  u',',
#  u'and',
#  u'both',
#  u'the',
#  u'book',
#  u'review',
#  u'and',
#  u'the',
#  u'daily',
#  u'new',
#  u'york',
#  u'times',
#  u'paid',
#  u'attention',
#  u',',
#  u'though',
#  u'king',
#  u'might',
#  u'have',
#  u'wished',
#  u'they',
#  u'had',
#  u"n't",
#  u':',
#  u'``',
#  u'to',
#  u'say',
#  u'that',
#  u'stephen',
#  u'king',
#  u'is',
#  u'not',
#  u'an',
#  u'elegant',
#  u'writer',
#  u',',
#  u"''",
#  u'jack',
#  u'sullivan',
#  u'groused',
#  u'in',
#  u'the',
#  u'book',
#  u'review',
#  u',',
#  u'``',
#  u'is',
#  u'putting',
#  u'it',
#  u'mildly',
#  u'.',
#  u"''",
#  u'the',
#  u'daily',
#  u"'s",
#  u'reviewer',
#  u',',
#  u'richard',
#  u'r.',
#  u'lingeman',
#  u',',
#  u'was',
#  u"n't",
#  u'much',
#  u'kinder',
#  u':',
#  u'``',
#  u'the',
#  u'evil',
#  u'is',
#  u'slapdash',
#  u',',
#  u'unfocused',
#  u'and',
#  u'eventually',
#  u'preposterous',
#  u',',
#  u"''",
#  u'he',
#  u'wrote',
#  u'.',
#  u'``',
#  u'king',
#  u'is',
#  u'a',
#  u'natural',
#  u',',
#  u'but',
#  u'he',
#  u'lacks',
#  u'control',
#  u';',
#  u'he',
#  u'simply',
#  u'rears',
#  u'back',
#  u'and',
#  u'lets',
#  u'fly',
#  u'with',
#  u'the',
#  u'fireball',
#  u',',
#  u'and',
#  u'a',
#  u'lot',
#  u'of',
#  u'wild',
#  u'pitches',
#  u'result',
#  u'.',
#  u"''",
#  u'the',
#  u'criticism',
#  u'apparently',
#  u'stung',
#  u'.',
#  u'``',
#  u'sales',
#  u'are',
#  u"n't",
#  u'all-important',
#  u',',
#  u"''",
#  u'king',
#  u'later',
#  u'told',
#  u'lingeman',
#  u'.',
#  u'``',
#  u'we',
#  u'all',
#  u'want',
#  u'to',
#  u'be',
#  u'nominated',
#  u'for',
#  u'a',
#  u'national',
#  u'book',
#  u'award',
#  u'.',
#  u"''",
#  u'i',
#  u'grew',
#  u'up',
#  u'reading',
#  u'king',
#  u',',
#  u'and',
#  u'the',
#  u'literary',
#  u'establishment',
#  u'has',
#  u'gradually',
#  u'come',
#  u'around',
#  u';',
#  u'in',
#  u'2003',
#  u',',
#  u'the',
#  u'national',
#  u'book',
#  u'foundation',
#  u'awarded',
#  u'him',
#  u'a',
#  u'medal',
#  u'for',
#  u'distinguished',
#  u'contribution',
#  u'to',
#  u'american',
#  u'letters',
#  u'.',
#  u'the',
#  u'ballad',
#  u'of',
#  u'jail',
#  u'reading',
#  u':',
#  u'in',
#  u'next',
#  u'week',
#  u"'s",
#  u'issue',
#  u',',
#  u'lauren',
#  u'groff',
#  u'will',
#  u'review',
#  u'peter',
#  u'orner',
#  u"'s",
#  u'new',
#  u'story',
#  u'collection',
#  u',',
#  u'``',
#  u'last',
#  u'car',
#  u'over',
#  u'the',
#  u'sagamore',
#  u'bridge',
#  u'.',
#  u"''",
#  u'orner',
#  u'has',
#  u'never',
#  u'hit',
#  u'the',
#  u'best-seller',
#  u'list',
#  u',',
#  u'despite',
#  u'critical',
#  u'acclaim',
#  u',',
#  u'but',
#  u'he',
#  u'did',
#  u'have',
#  u'a',
#  u'recent',
#  u'brush',
#  u'with',
#  u'the',
#  u'wilder',
#  u'side',
#  u'of',
#  u'popular',
#  u'fiction',
#  u'-',
#  u'as',
#  u'the',
#  u'expert',
#  u'witness',
#  u'in',
#  u'a',
#  u'lawsuit',
#  u'involving',
#  u'a',
#  u'california',
#  u'prisoner',
#  u"'s",
#  u'right',
#  u'to',
#  u'read',
#  u'werewolf',
#  u'erotica',
#  u'.',
#  u'(',
#  u'the',
#  u'plaintiff',
#  u',',
#  u'an',
#  u'inmate',
#  u'at',
#  u'pelican',
#  u'bay',
#  u'state',
#  u'prison',
#  u',',
#  u'successfully',
#  u'appealed',
#  u'after',
#  u'his',
#  u'copy',
#  u'of',
#  u'mathilde',
#  u'madden',
#  u"'s",
#  u'``',
#  u'silver',
#  u'crown',
#  u"''",
#  u'was',
#  u'confiscated',
#  u'.',
#  u')',
#  u'``',
#  u'at',
#  u'stake',
#  u'in',
#  u'the',
#  u'case',
#  u'was',
#  u'the',
#  u'very',
#  u'tricky',
#  u'and',
#  u'very',
#  u'subjective',
#  u'issue',
#  u'of',
#  u'literary',
#  u'value',
#  u',',
#  u"''",
#  u'orner',
#  u'told',
#  u'me',
#  u'via',
#  u'e-mail',
#  u'.',
#  u'``',
#  u'as',
#  u'a',
#  u'fiction',
#  u'writer',
#  u',',
#  u'you',
#  u'ca',
#  u"n't",
#  u'really',
#  u'say',
#  u'no',
#  u'when',
#  u'someone',
#  u'asks',
#  u'you',
#  u'to',
#  u'read',
#  u'some',
#  u'werewolf',
#  u'erotica',
#  u',',
#  u'especially',
#  u'for',
#  u'a',
#  u'good',
#  u'cause',
#  u'.',
#  u'and',
#  u'i',
#  u"'d",
#  u'say',
#  u'the',
#  u'right',
#  u'to',
#  u'read',
#  u',',
#  u'wherever',
#  u'you',
#  u'are',
#  u',',
#  u'is',
#  u'a',
#  u'pretty',
#  u'good',
#  u'cause',
#  u'.',
#  u"''",
#  u'orner',
#  u'ended',
#  u'up',
#  u'``',
#  u'tearing',
#  u'through',
#  u"''",
#  u'the',
#  u'book',
#  u',',
#  u'he',
#  u'said',
#  u'.',
#  u'``',
#  u'i',
#  u'tend',
#  u'to',
#  u'be',
#  u'a',
#  u'very',
#  u'slow',
#  u'reader',
#  u'.',
#  u'i',
#  u'read',
#  u"'the",
#  u'silver',
#  u'crown',
#  u"'",
#  u'fast',
#  u'-',
#  u'the',
#  u'prose',
#  u'really',
#  u'moves',
#  u',',
#  u'let',
#  u"'s",
#  u'say',
#  u'.',
#  u'i',
#  u'wish',
#  u'i',
#  u'had',
#  u'as',
#  u'much',
#  u'action',
#  u'in',
#  u'my',
#  u'own',
#  u'books',
#  u'.',
#  u"''",
#  u'orner',
#  u'studied',
#  u'law',
#  u',',
#  u'and',
#  u'has',
#  u'worked',
#  u'in',
#  u'prisons',
#  u'both',
#  u'in',
#  u'a',
#  u'legal',
#  u'capacity',
#  u'and',
#  u'as',
#  u'a',
#  u'writing',
#  u'teacher',
#  u'.',
#  u'he',
#  u"'s",
#  u'sympathetic',
#  u',',
#  u'he',
#  u'told',
#  u'me',
#  u',',
#  u'to',
#  u'their',
#  u'challenges',
#  u'.',
#  u'but',
#  u'he',
#  u'would',
#  u'tend',
#  u'to',
#  u'allow',
#  u'most',
#  u'books',
#  u'.',
#  u'``',
#  u'correctional',
#  u'officers',
#  u'have',
#  u'to',
#  u'enforce',
#  u'discipline',
#  u'in',
#  u'an',
#  u'incredibly',
#  u'tough',
#  u'environment',
#  u',',
#  u"''",
#  u'he',
#  u'said',
#  u'.',
#  u'``',
#  u'pelican',
#  u'bay',
#  u'is',
#  u'one',
#  u'of',
#  u'the',
#  u'most',
#  u'violent',
#  u'prisons',
#  u'in',
#  u'california',
#  u'.',
#  u'.',
#  u'.',
#  u'.',
#  u'they',
#  u"'ve",
#  u'got',
#  u'some',
#  u'extraordinarily',
#  u'serious',
#  u'problems',
#  u'.',
#  u'my',
#  u'humble',
#  u'thought',
#  u',',
#  u'speaking',
#  u'as',
#  u'a',
#  u'writer',
#  u',',
#  u'is',
#  u'that',
#  u'an',
#  u'inmate',
#  u'reading',
#  u'a',
#  u'book',
#  u'about',
#  u'werewolves',
#  u'having',
#  u'sex',
#  u'is',
#  u'the',
#  u'least',
#  u'of',
#  u'their',
#  u'problems',
#  u'.',
#  u"''"]

# %%
# http://text-processing.com/demo/tokenize/
len(set(tokenized_docs[2]))
# Out:
# 282

# %% [markdown]
# # Vectorizing "documents" as a *Bag of Words*
# # $
# \begin{array}{|c|c|c|c|c|}
# \hline
# & \text{token 1} &  \text{token 2} & \cdots &\text{token p} \\ \hline
# \text{document 1} &&&& \\ \hline
# \text{document 2} &&&& \\ \hline
# \vdots &&&& \\ \hline
# \text{document n} &&&& \\ \hline
# \end{array}
# $
#
# # How big is $n$?
#
#
# # How big is $p$?

# %% [markdown]
# # Addressing $p$:
# # - stop words
# # - punctuation/whitespace
# # - stemming/lemmatizing

# %%
from nltk.corpus import stopwords
#nltk.download('stopwords')
sw = set(stopwords.words('english'))

# %%
sw
# Out:
# {u'a',
#  u'about',
#  u'above',
#  u'after',
#  u'again',
#  u'against',
#  u'ain',
#  u'all',
#  u'am',
#  u'an',
#  u'and',
#  u'any',
#  u'are',
#  u'aren',
#  u'as',
#  u'at',
#  u'be',
#  u'because',
#  u'been',
#  u'before',
#  u'being',
#  u'below',
#  u'between',
#  u'both',
#  u'but',
#  u'by',
#  u'can',
#  u'couldn',
#  u'd',
#  u'did',
#  u'didn',
#  u'do',
#  u'does',
#  u'doesn',
#  u'doing',
#  u'don',
#  u'down',
#  u'during',
#  u'each',
#  u'few',
#  u'for',
#  u'from',
#  u'further',
#  u'had',
#  u'hadn',
#  u'has',
#  u'hasn',
#  u'have',
#  u'haven',
#  u'having',
#  u'he',
#  u'her',
#  u'here',
#  u'hers',
#  u'herself',
#  u'him',
#  u'himself',
#  u'his',
#  u'how',
#  u'i',
#  u'if',
#  u'in',
#  u'into',
#  u'is',
#  u'isn',
#  u'it',
#  u'its',
#  u'itself',
#  u'just',
#  u'll',
#  u'm',
#  u'ma',
#  u'me',
#  u'mightn',
#  u'more',
#  u'most',
#  u'mustn',
#  u'my',
#  u'myself',
#  u'needn',
#  u'no',
#  u'nor',
#  u'not',
#  u'now',
#  u'o',
#  u'of',
#  u'off',
#  u'on',
#  u'once',
#  u'only',
#  u'or',
#  u'other',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'out',
#  u'over',
#  u'own',
#  u're',
#  u's',
#  u'same',
#  u'shan',
#  u'she',
#  u'should',
#  u'shouldn',
#  u'so',
#  u'some',
#  u'such',
#  u't',
#  u'than',
#  u'that',
#  u'the',
#  u'their',
#  u'theirs',
#  u'them',
#  u'themselves',
#  u'then',
#  u'there',
#  u'these',
#  u'they',
#  u'this',
#  u'those',
#  u'through',
#  u'to',
#  u'too',
#  u'under',
#  u'until',
#  u'up',
#  u've',
#  u'very',
#  u'was',
#  u'wasn',
#  u'we',
#  u'were',
#  u'weren',
#  u'what',
#  u'when',
#  u'where',
#  u'which',
#  u'while',
#  u'who',
#  u'whom',
#  u'why',
#  u'will',
#  u'with',
#  u'won',
#  u'wouldn',
#  u'y',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves'}

# %%
toc_doc = []
for document in tokenized_docs:
    doc = []
    for token in document:
        if token not in sw:
            doc.append(token)
    toc_doc.append(doc)
    
tokenized_docs = toc_doc

# %%
import string
sp = set(string.punctuation)
sp.add('``')
sp.add("''")
sp
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "''",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '``',
#  '{',
#  '|',
#  '}',
#  '~'}

# %%
toc_doc = []
for document in tokenized_docs:
    doc = []
    for token in document:
        if token not in sp:
            doc.append(token)
    toc_doc.append(doc)
    
tokenized_docs = toc_doc

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#nltk.download('wordnet')

porter = PorterStemmer()
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()

# %%
import copy
tokenized_docs_porter = copy.deepcopy(tokenized_docs)
tokenized_docs_snowball = copy.deepcopy(tokenized_docs)
tokenized_docs_lemmatize = copy.deepcopy(tokenized_docs)
for document in range(len(tokenized_docs)):
    for token in range(len(tokenized_docs[document])):
        tokenized_docs_porter[document][token] = porter.stem(tokenized_docs[document][token])
        tokenized_docs_snowball[document][token] = snowball.stem(tokenized_docs[document][token])
        tokenized_docs_lemmatize[document][token] = wordnet.lemmatize(tokenized_docs[document][token])

# %%
documents[2]
# Out:
# u'\n\n\n\n\n\n\n\n\n\n\n\'shining\' star: "doctor sleep," stephen king\'s much-\xe2\xadanticipated sequel to "the shining," isn\'t on the hardcover list yet - its official release date is sept. 24 - but back in 1977, "the shining" did spend time there on its way to becoming a cultural touchstone. (it also sold well in paperback, especially after stanley kubrick\'s 1980 film adaptation.)        \n \n\n"the shining" was king\'s third novel, and both the book review and the daily new york times paid attention, though king might have wished they hadn\'t: "to say that stephen king is not an elegant writer," jack sullivan groused in the book review, "is putting it mildly." the daily\'s reviewer, richard r. lingeman, wasn\'t much kinder: "the evil is slapdash, unfocused and eventually preposterous," he wrote. "king is a natural, but he lacks control; he simply rears back and lets fly with the fireball, and a lot of wild pitches result." the criticism apparently stung. "sales aren\'t all-important," king later told lingeman. "we all want to be nominated for a national book award." i grew up reading king, and the literary establishment has gradually come around; in 2003, the national book foundation awarded him a medal for distinguished contribution to american letters.        \nthe ballad of jail reading: in next week\'s issue, lauren groff will review peter orner\'s new story collection, "last car over the sagamore bridge." orner has never hit the best-seller list, despite critical acclaim, but he did have a recent brush with the wilder side of popular fiction - as the expert witness in a lawsuit involving a california prisoner\'s right to read werewolf erotica. (the plaintiff, an inmate at pelican bay state prison, successfully appealed after his copy of mathilde madden\'s "silver crown" was confiscated.)        \n"at stake in the case was the very tricky and very subjective issue of literary value," orner told me via e-mail. "as a fiction writer, you can\'t really say no when someone asks you to read some werewolf erotica, especially for a good cause. and i\'d say the right to read, wherever you are, is a pretty good cause." orner ended up "tearing through" the book, he said. "i tend to be a very slow reader. i read \'the silver crown\' fast - the prose really moves, let\'s say. i wish i had as much action in my own books."        \norner studied law, and has worked in prisons both in a legal capacity and as a writing teacher. he\'s sympathetic, he told me, to their challenges. but he would tend to allow most books. "correctional officers have to enforce discipline in an incredibly tough environment," he said. "pelican bay is one of the most violent prisons in california. . . . they\'ve got some extraordinarily serious problems. my humble thought, speaking as a writer, is that an inmate reading a book about werewolves having sex is the least of their problems."        \n\n\n\n \n\n\n\n'

# %%
tokenized_docs[2]
# Out:
# [u"'shining",
#  u'star',
#  u'doctor',
#  u'sleep',
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticipated',
#  u'sequel',
#  u'shining',
#  u"n't",
#  u'hardcover',
#  u'list',
#  u'yet',
#  u'official',
#  u'release',
#  u'date',
#  u'sept.',
#  u'24',
#  u'back',
#  u'1977',
#  u'shining',
#  u'spend',
#  u'time',
#  u'way',
#  u'becoming',
#  u'cultural',
#  u'touchstone',
#  u'also',
#  u'sold',
#  u'well',
#  u'paperback',
#  u'especially',
#  u'stanley',
#  u'kubrick',
#  u"'s",
#  u'1980',
#  u'film',
#  u'adaptation',
#  u'shining',
#  u'king',
#  u"'s",
#  u'third',
#  u'novel',
#  u'book',
#  u'review',
#  u'daily',
#  u'new',
#  u'york',
#  u'times',
#  u'paid',
#  u'attention',
#  u'though',
#  u'king',
#  u'might',
#  u'wished',
#  u"n't",
#  u'say',
#  u'stephen',
#  u'king',
#  u'elegant',
#  u'writer',
#  u'jack',
#  u'sullivan',
#  u'groused',
#  u'book',
#  u'review',
#  u'putting',
#  u'mildly',
#  u'daily',
#  u"'s",
#  u'reviewer',
#  u'richard',
#  u'r.',
#  u'lingeman',
#  u"n't",
#  u'much',
#  u'kinder',
#  u'evil',
#  u'slapdash',
#  u'unfocused',
#  u'eventually',
#  u'preposterous',
#  u'wrote',
#  u'king',
#  u'natural',
#  u'lacks',
#  u'control',
#  u'simply',
#  u'rears',
#  u'back',
#  u'lets',
#  u'fly',
#  u'fireball',
#  u'lot',
#  u'wild',
#  u'pitches',
#  u'result',
#  u'criticism',
#  u'apparently',
#  u'stung',
#  u'sales',
#  u"n't",
#  u'all-important',
#  u'king',
#  u'later',
#  u'told',
#  u'lingeman',
#  u'want',
#  u'nominated',
#  u'national',
#  u'book',
#  u'award',
#  u'grew',
#  u'reading',
#  u'king',
#  u'literary',
#  u'establishment',
#  u'gradually',
#  u'come',
#  u'around',
#  u'2003',
#  u'national',
#  u'book',
#  u'foundation',
#  u'awarded',
#  u'medal',
#  u'distinguished',
#  u'contribution',
#  u'american',
#  u'letters',
#  u'ballad',
#  u'jail',
#  u'reading',
#  u'next',
#  u'week',
#  u"'s",
#  u'issue',
#  u'lauren',
#  u'groff',
#  u'review',
#  u'peter',
#  u'orner',
#  u"'s",
#  u'new',
#  u'story',
#  u'collection',
#  u'last',
#  u'car',
#  u'sagamore',
#  u'bridge',
#  u'orner',
#  u'never',
#  u'hit',
#  u'best-seller',
#  u'list',
#  u'despite',
#  u'critical',
#  u'acclaim',
#  u'recent',
#  u'brush',
#  u'wilder',
#  u'side',
#  u'popular',
#  u'fiction',
#  u'expert',
#  u'witness',
#  u'lawsuit',
#  u'involving',
#  u'california',
#  u'prisoner',
#  u"'s",
#  u'right',
#  u'read',
#  u'werewolf',
#  u'erotica',
#  u'plaintiff',
#  u'inmate',
#  u'pelican',
#  u'bay',
#  u'state',
#  u'prison',
#  u'successfully',
#  u'appealed',
#  u'copy',
#  u'mathilde',
#  u'madden',
#  u"'s",
#  u'silver',
#  u'crown',
#  u'confiscated',
#  u'stake',
#  u'case',
#  u'tricky',
#  u'subjective',
#  u'issue',
#  u'literary',
#  u'value',
#  u'orner',
#  u'told',
#  u'via',
#  u'e-mail',
#  u'fiction',
#  u'writer',
#  u'ca',
#  u"n't",
#  u'really',
#  u'say',
#  u'someone',
#  u'asks',
#  u'read',
#  u'werewolf',
#  u'erotica',
#  u'especially',
#  u'good',
#  u'cause',
#  u"'d",
#  u'say',
#  u'right',
#  u'read',
#  u'wherever',
#  u'pretty',
#  u'good',
#  u'cause',
#  u'orner',
#  u'ended',
#  u'tearing',
#  u'book',
#  u'said',
#  u'tend',
#  u'slow',
#  u'reader',
#  u'read',
#  u"'the",
#  u'silver',
#  u'crown',
#  u'fast',
#  u'prose',
#  u'really',
#  u'moves',
#  u'let',
#  u"'s",
#  u'say',
#  u'wish',
#  u'much',
#  u'action',
#  u'books',
#  u'orner',
#  u'studied',
#  u'law',
#  u'worked',
#  u'prisons',
#  u'legal',
#  u'capacity',
#  u'writing',
#  u'teacher',
#  u"'s",
#  u'sympathetic',
#  u'told',
#  u'challenges',
#  u'would',
#  u'tend',
#  u'allow',
#  u'books',
#  u'correctional',
#  u'officers',
#  u'enforce',
#  u'discipline',
#  u'incredibly',
#  u'tough',
#  u'environment',
#  u'said',
#  u'pelican',
#  u'bay',
#  u'one',
#  u'violent',
#  u'prisons',
#  u'california',
#  u"'ve",
#  u'got',
#  u'extraordinarily',
#  u'serious',
#  u'problems',
#  u'humble',
#  u'thought',
#  u'speaking',
#  u'writer',
#  u'inmate',
#  u'reading',
#  u'book',
#  u'werewolves',
#  u'sex',
#  u'least',
#  u'problems']

# %%
tokenized_docs[2][:10]
# Out:
# [u"'shining",
#  u'star',
#  u'doctor',
#  u'sleep',
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticipated',
#  u'sequel',
#  u'shining']

# %%
tokenized_docs_porter[2][:10]
# Out:
# [u"'shine",
#  u'star',
#  u'doctor',
#  u'sleep',
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticip',
#  u'sequel',
#  u'shine']

# %%
tokenized_docs_snowball[2][:10]
# Out:
# [u'shine',
#  u'star',
#  u'doctor',
#  u'sleep',
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticip',
#  u'sequel',
#  u'shine']

# %%
tokenized_docs_lemmatize[2][:10]
# Out:
# [u"'shining",
#  u'star',
#  u'doctor',
#  u'sleep',
#  u'stephen',
#  u'king',
#  u"'s",
#  u'much-\xe2\xadanticipated',
#  u'sequel',
#  u'shining']

# %%
vocab = list(set([t for d in tokenized_docs_porter for t in d ]))

# %%
vocab = {v:i for i,v in enumerate(vocab)}

# %%
" ".join(tokenized_docs_porter[2])
# Out:
# u"'shine star doctor sleep stephen king 's much-\xe2\xadanticip sequel shine n't hardcov list yet offici releas date sept. 24 back 1977 shine spend time way becom cultur touchston also sold well paperback especi stanley kubrick 's 1980 film adapt shine king 's third novel book review daili new york time paid attent though king might wish n't say stephen king eleg writer jack sullivan grous book review put mildli daili 's review richard r. lingeman n't much kinder evil slapdash unfocus eventu preposter wrote king natur lack control simpli rear back let fli firebal lot wild pitch result critic appar stung sale n't all-import king later told lingeman want nomin nation book award grew read king literari establish gradual come around 2003 nation book foundat award medal distinguish contribut american letter ballad jail read next week 's issu lauren groff review peter orner 's new stori collect last car sagamor bridg orner never hit best-sel list despit critic acclaim recent brush wilder side popular fiction expert wit lawsuit involv california prison 's right read werewolf erotica plaintiff inmat pelican bay state prison success appeal copi mathild madden 's silver crown confisc stake case tricki subject issu literari valu orner told via e-mail fiction writer ca n't realli say someon ask read werewolf erotica especi good caus 'd say right read wherev pretti good caus orner end tear book said tend slow reader read 'the silver crown fast prose realli move let 's say wish much action book orner studi law work prison legal capac write teacher 's sympathet told challeng would tend allow book correct offic enforc disciplin incred tough environ said pelican bay one violent prison california 've got extraordinarili seriou problem humbl thought speak writer inmat read book werewolv sex least problem"

# %%
import numpy as np
TF = np.zeros([len(tokenized_docs_porter), len(vocab)])

# %%
for d in range(len(tokenized_docs_porter)):
    for t in range(len(tokenized_docs_porter[d])):
        TF[d,vocab[tokenized_docs_porter[d][t]]] += 1

# %% [markdown]
# # Vocabulary, Corpus
# # Term Frequency, Presence/Absence, Document Frequency
# # $
# \begin{array}{|c|c|c|c|c|}
# \hline
# & \text{token 1} &  \text{token 2} & \cdots &\text{token p} \\ \hline
# \text{document 1} &&&& \\ \hline
# \text{document 2} &&&& \\ \hline
# \vdots &&&& \\ \hline
# \text{document n} &&&& \\ \hline
# \end{array}
# $

# %% [markdown]
# # Inverse Document Frequencing Weighting
#
# # $$TF\text{-}IDF_{ij} = TF_{ij}\times\log\left(1 + \frac{n}{1+DF_{j}}\right) $$

# %% [markdown]
# # Normalizing
#
# # $$^*TF\text{-}IDF_{ij} = \frac{TF\text{-}IDF_{ij}}{\sum_{j=1}^p TF\text{-}IDF_{ij}}$$
#
# # $$^{**}TF\text{-}IDF_{ij} = \frac{TF\text{-}IDF_{ij}}{\sqrt{\sum_{j=1}^p TF\text{-}IDF_{ij}^2}}$$
#
#
# <br>
# <font color="red">
# # What makes two documents similar?
# <br>
#
# <img src="stuff/Image529.gif",width=500px, align="left", Image529.gif>

# %% [markdown]
# # The dot product of two vectors $X_1$ and $X_2$ depends on their magnitude and the angle $\theta$ between them:
# # $$ \frac{X_1 \cdot X_2}{||X_1|| \; ||X_2||} = Cos(\theta)$$

# %%
DF = (TF>0).sum(axis=0)#/len(TF)
DF.shape
# plt.hist(DF)
# DF.min()
# Out:
# (28722,)

# %%
TF_IDF = TF*(np.log(1+len(TF)/(0.+DF)))

# %%
for tf in range(len(TF_IDF)):
    TF_IDF[tf] = TF_IDF[tf]/np.sqrt(np.sum(TF_IDF[tf]**2))

# %%
TF_IDF.dot(TF_IDF.T)[2].argsort()
# Out:
# array([723, 727, 728, 154, 954, 306, 721, 722, 152,  28, 175, 521, 724,
#         27, 817, 415, 308, 683, 284, 104,  25, 899, 462, 155, 700, 263,
#        951, 631, 501, 414, 268, 704, 475,  83, 924, 500, 203, 874, 292,
#        239, 269, 952, 307, 223, 434,  10, 644, 298, 417, 730, 587, 115,
#        438, 424, 804, 471,  19, 868, 517, 928, 432, 655,  91,  87, 563,
#        720,  26, 413,   5, 198, 294, 825, 151, 807, 477, 302, 851, 538,
#        289, 293,  49, 939, 680,  70, 262, 190, 920, 409, 948,  15, 823,
#        912,  39, 252, 648, 425, 572,  94, 947, 257, 250, 410, 963, 313,
#        430, 222, 506,  81, 854, 599, 712,  16,  77, 167, 576, 369, 366,
#        735, 264, 726, 662, 958, 116, 673, 759, 347,  69, 199,  89, 359,
#        100, 957, 814,  35, 206, 372, 360, 212, 915,  80,  55, 798, 686,
#        752, 715, 157, 412, 337, 460,  65, 312, 473, 610, 542, 121, 511,
#        945, 238,  48, 419, 640, 455, 667, 149, 185, 749, 377, 827, 796,
#        111, 739, 227, 450, 204, 474, 558, 664, 808, 561, 663, 528, 255,
#        932, 872, 219, 671, 433, 399, 840, 925, 708, 592, 977, 402, 949,
#        975, 891, 857, 929,  32, 613,  86, 327, 429, 765, 351, 652, 138,
#         75, 706, 687,  61,   3, 904, 893, 889, 632, 850, 956, 879, 274,
#        690, 665, 466, 168, 207, 505, 562, 489, 467, 520,  54, 628, 174,
#         72, 826, 182, 645, 635, 317, 855, 341, 630, 596, 742, 165, 967,
#        265, 355, 220, 523, 878,  17, 479, 310,  84, 638,  34, 846, 646,
#        113, 242, 781, 575, 352, 194,  68, 617,  42, 636, 508, 509, 333,
#        634, 248, 180, 497,  40, 225, 491,  85, 919, 553, 448, 936, 230,
#        642, 195, 461, 380, 246, 586,  58, 913, 574, 560,  12, 961,  43,
#        598, 698, 339, 809, 326, 329, 890, 717, 525, 803, 935, 279, 589,
#         93, 674,  78, 324, 548, 350,  53, 896, 441, 830, 590, 718, 616,
#        101, 805, 181, 443, 184, 842,  31, 390, 297, 837, 472, 272,  57,
#        379, 200, 213, 439, 942, 186, 684, 974, 725, 247, 539, 546, 217,
#        970, 877, 368, 800, 740,  71, 261, 437,  79, 378, 354, 488, 384,
#        559, 651, 583, 885, 824, 940, 566, 581, 914, 543, 856, 729, 270,
#        979, 287, 160,   0, 451,  13, 386, 573, 619, 233, 584, 819, 416,
#        980, 231, 367, 641, 527, 972,  44, 588,  76, 422,   7, 389, 325,
#        820, 234,   1, 938, 109, 447, 845,  14, 744, 469, 709, 147, 395,
#        882, 551, 131, 881, 494, 470, 775, 105, 908, 423, 770, 215, 513,
#         11,  99,  50, 884, 685, 682, 757, 637, 278, 863, 931, 256, 357,
#        922, 401,   4, 585,  22, 531, 821, 411, 978, 407, 971, 544, 487,
#        743,  51, 228, 177,  98, 571, 615, 173, 465, 864, 751, 435, 605,
#        911, 405, 244, 338, 761, 176,  20, 593, 374, 677, 756, 529, 760,
#        705,  47, 875, 456, 892, 550, 172, 196, 139, 249, 440, 873, 125,
#        909, 285, 202, 678, 457, 162, 933, 119, 134, 373, 132, 464, 623,
#        510, 604, 346, 813, 753, 633, 959, 484,  73, 552,  23, 392, 283,
#        444, 418, 127, 445, 710, 647, 106, 237, 156, 396, 689, 964, 426,
#          6, 129, 897, 323, 458, 880, 103, 569, 514, 120, 711, 658, 164,
#        966, 810, 468, 887, 108,  52, 221, 758, 609, 388, 818, 288, 600,
#        319, 524, 503, 276, 394, 650, 797, 540, 322, 214, 481, 316, 876,
#        666, 693, 314, 493, 145, 755, 158, 653, 478, 950, 122, 946, 714,
#        620, 516, 153, 694, 236, 703, 216,  88, 370, 282, 702, 363, 656,
#        748, 901, 577, 625, 716,  24, 226, 232,  33,  30, 594, 738, 286,
#        923, 732, 802, 731,   9, 530, 305, 251, 661, 746, 624,  64, 659,
#        865, 459, 280, 608, 567,   8, 843, 144,  74, 852,  46,  90, 376,
#         21, 701, 839, 902, 170, 382, 937, 669, 894, 146, 556, 240, 976,
#        860,  97, 754, 691, 344, 141, 161,  62, 431, 841, 660, 697, 224,
#        476, 670, 404, 133, 844, 403, 495, 454, 107, 762, 504,  95, 692,
#        406, 371, 334, 736, 771, 273,  18, 331, 335, 304, 112, 886, 943,
#        773, 490, 611, 681, 606, 449, 150, 446, 110, 178, 580, 905, 159,
#        427, 639, 123, 191, 618, 688, 828, 769, 126, 555, 428, 926, 398,
#        649, 533, 205, 603, 254, 695, 733, 349, 381, 301,  63, 241, 243,
#        626, 622, 482, 907, 318, 208, 143, 895, 420, 953, 345, 750, 831,
#        900, 591, 554, 211, 486, 612, 142, 871, 480, 657, 614,  96,  60,
#        498, 193, 734, 258, 140, 400, 365, 128, 311, 675, 833, 183, 148,
#        296, 442, 699,  82, 375, 903, 981, 163, 564,  56, 676, 815, 921,
#        499, 962,  36, 364, 713, 668, 888, 277, 315, 483,  29, 515, 336,
#        883, 291, 245, 135, 137, 210, 235, 485, 260, 547, 383, 330, 549,
#        853, 944, 118, 518, 507, 519, 557, 847, 745, 332, 275, 654, 849,
#        343, 836, 822, 866, 512, 452, 290, 271, 780, 463, 136, 526,  45,
#        492, 397, 832, 166, 607, 522, 342, 696, 300, 320, 812, 927, 719,
#        124, 969, 259, 867, 579, 266, 848, 811, 861, 218, 299, 918, 362,
#        171, 361, 968, 130, 453, 835, 973, 267, 643,  38, 309, 764, 358,
#        295, 906, 707, 816, 201, 627,  92, 102, 541, 393, 930, 387, 862,
#        768, 767, 794, 838, 169, 535, 785, 496, 672, 188, 536, 788, 679,
#         67, 983, 982, 391, 565, 353,  37, 784, 898, 777, 941, 965, 281,
#        179, 629, 870, 795, 348, 570, 917, 793, 229, 602, 303, 772, 582,
#        801, 209, 799,  41, 117, 829, 787, 385, 621, 792, 568, 791, 916,
#        578, 597, 790, 328, 545, 776, 789, 910, 806, 960, 779, 534, 747,
#        436,  66, 834, 955, 408, 737, 537, 774, 114, 741, 858, 321, 187,
#        189, 786, 192, 502,  59, 934, 778, 421, 197, 356, 340, 783, 601,
#        763, 869, 766, 859, 253, 532, 595, 782,   2])

# %%
documents[782]
# Out:
# u'\n\n\n\n\n\n\n\n\n\n\nfor the past 12 years, since his lauded "esther stories," peter orner has been engaged in a strange, quiet and wonderful experiment. he has written four works of fiction - two novels and two story collections - all composed of canny snippets that build with subtle accumulative power to create books autobiographical in feel, if not necessarily in fact. in all but his first novel, "the second coming of mavala shikongo," the books return to the same characters from startling vantage points; orner is writing in spirals, moving restlessly out to embody imagined characters, but always returning to the chicago and fall river, mass., family of his most frequent first-person narrator, a young man who is roughly his age. in each of his books, orner\'s crystalline sentences and his ability to pay close and sustained attention to small moments transform the ordinary elements of each story into an even more astonishing whole.        \n \n\n"last car over the sagamore bridge," orner\'s new collection, is composed of 52 stories, most no longer than a few pages. there are many strands running through the weave of this book: one is a series featuring the above-mentioned family, another is a group of italicized first-person stories, another imagines people outside of the central character/narrator\'s experience, like a woman who sells television antennas in a mexico city plaza and a serbian woman sitting in a coffee shop. yet another strand observes famous people: mary todd lincoln, richard j. daley, ted kennedy, geraldo rivera and isaac babel, one of many writers with whom orner is in conversation. (chekhov is another clear influence, as is the evan s. connell of "mr. bridge" and "mrs. bridge," novels written in the same episodic manner orner favors.)        \nat his strongest, orner can nail interior monologue in a way that recalls grace paley. just listen to the voice of walt kaplan, a character who also appears in "esther stories" and in the novel "love and shame and love":        \n"would my head were a head of lettuce. i drove the last car over the sagamore bridge before the state police closed it off. the cape cod canal all atempest beneath. no cars coming, no cars going. the bridge cables flapping like rubber bands. you think in certain circumstances a few thousand feet of bridge isn\'t a thousand miles?"        \na writer who keeps returning to the same subjects runs a big risk. the reader can feel like an invisible observer in a room walled with mirrors, watching the author fascinated by the endless reflections of himself. just when you think he\'s finished examining this interesting feature, here it is again from a different angle. when orner returns too often to the same beat or idea, he can almost reverse the effects of his truest gift, which is the ability to take elements we\'ve seen before - the historical characters, the suburbs, the tight-knit jewish families, chicago - and, by the force of his fascination, make them thrillingly strange. this talent never fails orner; yet when he looks too often at the same loss or character or mood, he teeters on the verge of returning the strange back to the familiar.        \nwhere would we be, though, without writers who take great risks? they are the interesting ones to follow from book to book. sometimes the risky writer stumbles in his funambulist guise, and you wonder if he\'s about to dive into the drink. in "last car over the sagamore bridge," orner is especially daring with structure. though the collection is organized into four loose sections based on what i interpret as loss, murder, longing and what remains after loss, it\'s difficult to understand why these stories had to appear in the same book. the leaps from historical character to internal narrative to apparent transcription make a reader a little dizzy. most great story collections - "jesus\' son," by denis johnson; "twilight of the superheroes," by deborah eisenberg; "varieties of disturbance," by l ...

# %% [markdown]
# # sklearn

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
vect = CountVectorizer(stop_words='english')
word_counts = vect.fit_transform(documents)

# %%
def tokenize(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''
    tokenized_doc = nltk.word_tokenize(doc)

    sw = set(stopwords.words('english'))
    
    toc_doc = []
    for token in tokenized_doc:
        if token not in sw:
            toc_doc.append(token)
    tokenized_doc = toc_doc  

    sp = set(string.punctuation)
    sp.add('``')
    sp.add("''")

    toc_doc = []
    for token in tokenized_doc:
        if token not in sp:
            toc_doc.append(token)
    tokenized_doc = toc_doc       

    tokenized_doc_porter = copy.deepcopy(tokenized_doc)
    for token in range(len(tokenized_doc)):
        tokenized_doc_porter[token] = porter.stem(tokenized_doc[token])
    
    return tokenized_doc_porter

vect = CountVectorizer(tokenizer=tokenize)
word_counts = vect.fit_transform(documents)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
j=1
plt.plot([TF[j][vocab[i]] for i in vect.get_feature_names()], word_counts.toarray()[j],'.')

# %%
vect = TfidfVectorizer(tokenizer=tokenize, smooth_idf=False)
word_counts = vect.fit_transform(documents)

# %% [raw]
# j=1
# plt.plot([TF_IDF[j][vocab[i]] for i in vect.get_feature_names()], word_counts.toarray()[j],'.')
# plt.plot([0,.5],[0,.5])

# %% [markdown]
# # spacy

# %%
# conda install spacy
# pip install spacy && python -m spacy.en.download
import spacy

# %%
nlp = spacy.load('en')

# %%
parsed_doc = nlp(documents[2])
parsed_doc
# Out:
# 'shining' star: "doctor sleep," stephen king's much-â­anticipated sequel to "the shining," isn't on the hardcover list yet - its official release date is sept. 24 - but back in 1977, "the shining" did spend time there on its way to becoming a cultural touchstone. (it also sold well in paperback, especially after stanley kubrick's 1980 film adaptation.)
#
#
# "the shining" was king's third novel, and both the book review and the daily new york times paid attention, though king might have wished they hadn't: "to say that stephen king is not an elegant writer," jack sullivan groused in the book review, "is putting it mildly." the daily's reviewer, richard r. lingeman, wasn't much kinder: "the evil is slapdash, unfocused and eventually preposterous," he wrote. "king is a natural, but he lacks control; he simply rears back and lets fly with the fireball, and a lot of wild pitches result." the criticism apparently stung. "sales aren't all-important," king later told lingeman. "we all want to be nominated for a national book award." i grew up reading king, and the literary establishment has gradually come around; in 2003, the national book foundation awarded him a medal for distinguished contribution to american letters.
# the ballad of jail reading: in next week's issue, lauren groff will review peter orner's new story collection, "last car over the sagamore bridge." orner has never hit the best-seller list, despite critical acclaim, but he did have a recent brush with the wilder side of popular fiction - as the expert witness in a lawsuit involving a california prisoner's right to read werewolf erotica. (the plaintiff, an inmate at pelican bay state prison, successfully appealed after his copy of mathilde madden's "silver crown" was confiscated.)
# "at stake in the case was the very tricky and very subjective issue of literary value," orner told me via e-mail. "as a fiction writer, you can't really say no when someone asks you to read some werewolf erotica, especially for a good cause. and i'd say the right to read, wherever you are, is a pretty good cause." orner ended up "tearing through" the book, he said. "i tend to be a very slow reader. i read 'the silver crown' fast - the prose really moves, let's say. i wish i had as much action in my own books."
# orner studied law, and has worked in prisons both in a legal capacity and as a writing teacher. he's sympathetic, he told me, to their challenges. but he would tend to allow most books. "correctional officers have to enforce discipline in an incredibly tough environment," he said. "pelican bay is one of the most violent prisons in california. . . . they've got some extraordinarily serious problems. my humble thought, speaking as a writer, is that an inmate reading a book about werewolves having sex is the least of their problems."

# %%
for i,s in enumerate(parsed_doc.sents):
    print i
    print s
# Out:
# 0
#
#
#
#
#
#
#
#
#
#
#
# 'shining' star: "doctor sleep," stephen king's much-â­anticipated sequel to "the shining," isn't on the hardcover list yet - its official release date is sept.
# 1
# 24 - but back in 1977, "the shining" did spend time there on its way to becoming a cultural touchstone.
# 2
# (it also sold well in paperback, especially after stanley kubrick's 1980 film adaptation.)
#
#
#
# 3
# "the shining" was king's third novel, and both the book review and the daily new york times paid attention, though king might have wished they hadn't: "to say that stephen king is not an elegant writer," jack sullivan groused in the book review, "is putting it mildly."
# 4
# the daily's reviewer, richard r. lingeman, wasn't much kinder:
# 5
# "the evil is slapdash, unfocused and eventually preposterous," he wrote.
# 6
# "king is a natural, but he lacks control; he simply rears back and lets fly with the fireball, and a lot of wild pitches result."
# 7
# the criticism apparently stung.
# 8
# "sales aren't all-important," king later told lingeman.
# 9
# "we all want to be nominated for a national book award.
# 10
# " i grew up reading king, and the literary establishment has gradually come around; in 2003, the national book foundation awarded him a medal for distinguished contribution to american letters.
#
# 11
# the ballad of jail reading: in next week's issue, lauren groff will review peter orner's new story collection, "last car over the sagamore bridge."
# 12
# orner has never hit the best-seller list, despite critical acclaim, but he did have a recent brush with the wilder side of popular fiction - as the expert witness in a lawsuit involving a california prisoner's right to read werewolf erotica.
# 13
# (the plaintiff, an inmate at pelican bay state prison, successfully appealed after his copy of mathilde madden's "silver crown" was confiscated.)
# "at stake in the case was the very tricky and very subjective issue of literary value," orner told me via e-mail. "as a fiction writer, you can't really say no when someone asks you to read some werewolf erotica, especially for a good cause.
# 14
# and i'd say the right to read, wherever you are, is a pretty good cause.
# 15
# "
# 16
# orner ended up "tearing through" the book, he said.
# 17
# "i tend to be a very slow reader.
# 18
# i read 'the silver crown' fast - the prose really moves, let's say.
# 19
# i wish i had as much action in my own books."
#
# 20
# orner studied law, and has worked in prisons both in a legal capacity and as a writing teacher.
# 21
# he's sympathetic, he told me, to their challenges.
# 22
# but he would tend to allow most books.
# 23
# "correctional officers have to enforce discipline in an incredibly tough environment," he said.
# 24
# "pelican bay is one of the most violent prisons in california. . . .
# 25
# they've got some extraordinarily serious problems.
# 26
# my humble thought, speaking as a writer, is that an inmate reading a book about werewolves having sex is the least of their problems."

# %%
for i,e in enumerate(parsed_doc.ents):
    print i, e, ": (", e.label_, ")"
# Out:
# 0 24 - but : ( CARDINAL )
# 1 1977 : ( DATE )
# 2 1980 : ( DATE )
# 3 third : ( ORDINAL )
# 4 daily : ( DATE )
# 5 2003 : ( DATE )
# 6 next week's : ( DATE )

# %%
import pandas as pd

text = [token.orth_ for token in parsed_doc]
post = [token.pos_ for token in parsed_doc]

pd.DataFrame(zip(text, post))
# Out:
#                             0      1
# 0      \n\n\n\n\n\n\n\n\n\n\n  SPACE
# 1                           '  PUNCT
# 2                     shining   VERB
# 3                           '  PUNCT
# 4                        star   NOUN
# 5                           :  PUNCT
# 6                           "  PUNCT
# 7                      doctor   NOUN
# 8                       sleep   NOUN
# 9                           ,  PUNCT
# 10                          "  PUNCT
# 11                    stephen    ADJ
# 12                       king   NOUN
# 13                         's   PART
# 14         much-â­anticipated   VERB
# 15                     sequel   NOUN
# 16                         to   PART
# 17                          "  PUNCT
# 18                        the    DET
# 19                    shining   VERB
# 20                          ,  PUNCT
# 21                          "  PUNCT
# 22                         is   VERB
# 23                        n't    ADV
# 24                         on    ADP
# 25                        the    DET
# 26                  hardcover   NOUN
# 27                       list   NOUN
# 28                        yet    ADV
# 29                          -  PUNCT
# ..                        ...    ...
# 588                         .  PUNCT
# 589                        my    ADJ
# 590                    humble    ADJ
# 591                   thought   NOUN
# 592                         ,  PUNCT
# 593                  speaking   VERB
# 594                        as    ADP
# 595                         a    DET
# 596                    writer   NOUN
# 597                         ,  PUNCT
# 598                        is   VERB
# 599                      that    ADP
# 600                        an    DET
# 601                    inmate   NOUN
# 602                   reading   VERB
# 603                         a    DET
# 604                      book   NOUN
# 605                     about    ADP
# 606                werewolves   NOUN
# 607                    having   VERB
# 608                       sex   NOUN
# 609                        is   VERB
# 610                       the    DET
# 611                     least    ADJ
# 612                        of    ADP
# 613                     their    ADJ
# 614                  problems   NOUN
# 615                         .  PUNCT
# 616                         "  PUNCT
# 617         \n\n\n\n \n\n\n\n  SPACE
#
# [618 rows x 2 columns]

# %%
ent_type = [token.ent_type_ for token in parsed_doc]
ent_iob = [token.ent_iob_ for token in parsed_doc]

pd.DataFrame(zip(text, ent_type, ent_iob))
# Out:
#                             0 1   2
# 0      \n\n\n\n\n\n\n\n\n\n\n     O
# 1                           '     O
# 2                     shining     O
# 3                           '     O
# 4                        star     O
# 5                           :     O
# 6                           "     O
# 7                      doctor     O
# 8                       sleep     O
# 9                           ,     O
# 10                          "     O
# 11                    stephen     O
# 12                       king     O
# 13                         's     O
# 14         much-â­anticipated     O
# 15                     sequel     O
# 16                         to     O
# 17                          "     O
# 18                        the     O
# 19                    shining     O
# 20                          ,     O
# 21                          "     O
# 22                         is     O
# 23                        n't     O
# 24                         on     O
# 25                        the     O
# 26                  hardcover     O
# 27                       list     O
# 28                        yet     O
# 29                          -     O
# ..                        ... .. ..
# 588                         .     O
# 589                        my     O
# 590                    humble     O
# 591                   thought     O
# 592                         ,     O
# 593                  speaking     O
# 594                        as     O
# 595                         a     O
# 596                    writer     O
# 597                         ,     O
# 598                        is     O
# 599                      that     O
# 600                        an     O
# 601                    inmate     O
# 602                   reading     O
# 603                         a     O
# 604                      book     O
# 605                     about     O
# 606                werewolves     O
# 607                    having     O
# 608                       sex     O
# 609                        is     O
# 610                       the     O
# 611                     least     O
# 612                        of     O
# 613                     their     O
# 614                  problems     O
# 615                         .     O
# 616                         "     O
# 617         \n\n\n\n \n\n\n\n     O
#
# [618 rows x 3 columns]

# %%
lemma = [token.lemma_ for token in parsed_doc]
shape = [token.shape_ for token in parsed_doc]

pd.DataFrame(zip(text, lemma, shape))
# Out:
#                             0                         1                      2
# 0      \n\n\n\n\n\n\n\n\n\n\n    \n\n\n\n\n\n\n\n\n\n\n               \n\n\n\n
# 1                           '                         '                      '
# 2                     shining                      shin                   xxxx
# 3                           '                         '                      '
# 4                        star                      star                   xxxx
# 5                           :                         :                      :
# 6                           "                         "                      "
# 7                      doctor                    doctor                   xxxx
# 8                       sleep                     sleep                   xxxx
# 9                           ,                         ,                      ,
# 10                          "                         "                      "
# 11                    stephen                   stephen                   xxxx
# 12                       king                      king                   xxxx
# 13                         's                        's                     'x
# 14         much-â­anticipated          much-â­anticipat            xxxx-x­xxxx
# 15                     sequel                    sequel                   xxxx
# 16                         to                        to                     xx
# 17                          "                         "                      "
# 18                        the                       the                    xxx
# 19                    shining                      shin                   xxxx
# 20                          ,                         ,                      ,
# 21                          "                         "                      "
# 22                         is                        be                     xx
# 23                        n't                       not                    x'x
# 24                         on                        on                     xx
# 25                        the                       the                    xxx
# 26                  hardcover                 hardcover                   xxxx
# 27                       list                      list                   xxxx
# 28                        yet                       yet                    xxx
# 29                          -                         -                      -
# ..                        ...                       ...                    ...
# 588                         .                         .                      .
# 589                        my                        my                     xx
# 590                    humble                    humble                   xxxx
# 591                   thought                   thought                   xxxx
# 592                         ,                         ,                      ,
# 593                  speaking                     speak                   xxxx
# 594                        as                        as                     xx
# 595                         a                         a                      x
# 596                    writer                    writer                   xxxx
# 597                         ,                         ,                      ,
# 598                        is                        be                     xx
# 599                      that                      that                   xxxx
# 600                        an                        an                     xx
# 601                    inmate                    inmate                   xxxx
# 602                   reading                      read                   xxxx
# 603                         a                         a                      x
# 604                      book                      book                   xxxx
# 605                     about                     about                   xxxx
# 606                werewolves                  werewolf                   xxxx
# 607                    having                      have                   xxxx
# 608                       sex                       sex                    xxx
# 609                        is                        be                     xx
# 610                       the                       the                    xxx
# 611                     least                     least                   xxxx
# 612                        of                        of                     xx
# 613                     their                     their                   xxxx
# 614                  problems                   problem                   xxxx
# 615                         .                         .                      .
# 616                         "                         "                      "
# 617         \n\n\n\n \n\n\n\n         \n\n\n\n \n\n\n\n      \n\n\n\n \n\n\n\n
#
# [618 rows x 3 columns]

# %%
stuffs = [(token.orth_, token.prob, token.is_stop, token.is_punct, token.is_space, token.like_num, token.is_oov) for token in parsed_doc]
ent_iob = [token.ent_iob_ for token in parsed_doc]

pd.DataFrame(stuffs, columns=["orth","log prob","is_stop","is_punct","is_space","like_num","is_oov"])
# Out:
#                          orth   log prob is_stop is_punct is_space like_num  \
# 0      \n\n\n\n\n\n\n\n\n\n\n -15.479972   False    False     True    False
# 1                           '  -6.737201   False     True    False    False
# 2                     shining -12.572595   False    False    False    False
# 3                           '  -6.737201   False     True    False    False
# 4                        star -10.276348   False    False    False    False
# 5                           :  -6.128876   False     True    False    False
# 6                           "  -5.026776   False     True    False    False
# 7                      doctor  -9.753222   False    False    False    False
# 8                       sleep  -9.394217   False    False    False    False
# 9                           ,  -3.454960   False     True    False    False
# 10                          "  -5.026776   False     True    False    False
# 11                    stephen -15.002590   False    False    False    False
# 12                       king -10.801839   False    False    False    False
# 13                         's  -4.830559   False    False    False    False
# 14         much-â­anticipated -19.502029   False    False    False    False
# 15                     sequel -11.565852   False    False    False    False
# 16                         to  -3.856022    True    False    False    False
# 17                          "  -5.026776   False     True    False    False
# 18                        the  -3.528767    True    False    False    False
# 19                    shining -12.572595   False    False    False    False
# 20                          ,  -3.454960   False     True    False    False
# 21                          "  -5.026776   False     True    False    False
# 22                         is  -4.457749    True    False    False    False
# 23                        n't  -4.859939   False    False    False    False
# 24                         on  -5.172736    True    False    False    False
# 25                        the  -3.528767    True    False    False    False
# 26                  hardcover -14.353661   False    False    False    False
# 27                       list  -8.819143   False    False    False    False
# 28                        yet  -8.229137    True    False    False    False
# 29                          -  -5.468655   False     True    False    False
# ..                        ...        ...     ...      ...      ...      ...
# 588                         .  -3.067898   False     True    False    False
# 589                        my  -5.491643    True    False    False    False
# 590                    humble -11.844897   False    False    False    False
# 591                   thought  -7.614910   False    False    False    False
# 592                         ,  -3.454960   False     True    False    False
# 593                  speaking  -9.958763   False    False    False    False
# 594                        as  -5.534485    True    False    False    False
# 595                         a  -3.929788    True    False    False    False
# 596                    writer -11.078810   False    False    False    False
# 597                         ,  -3.454960   False     True    False    False
# 598                        is  -4.457749    True    False    False    False
# 599                      that  -4.464505    True    False    False    False
# 600                        an  -6.014852    True    False    False    False
# 601                    inmate -13.985544   False    False    False    False
# 602                   reading  -8.832089   False    False    False    False
# 603                         a  -3.929788    True    False    False    False
# 604                      book  -8.741754   False    False    False    False
# 605                     about  -5.906809    True    False    False    False
# 606                werewolves -14.225866   False    False    False    False
# 607                    having  -7.818793   False    False    False    False
# 608                       sex  -8.613863   False    False    False    False
# 609                        is  -4.457749    True    False    False    False
# 610                       the  -3.528767    True    False    False    False
# 611                     least  -7.766009    True    False    False    False
# 612                        of  -4.275874    True    False    False    False
# 613                     their  -6.461464    True    False    False    False
# 614                  problems  -8.860827   False    False    False    False
# 615                         .  -3.067898   False     True    False    False
# 616                         "  -5.026776   False     True    False    False
# 617         \n\n\n\n \n\n\n\n -19.502029   False    False     True    False
#
#     is_oov
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13   False
# 14    True
# 15   False
# 16   False
# 17   False
# 18   False
# 19   False
# 20   False
# 21   False
# 22   False
# 23   False
# 24   False
# 25   False
# 26   False
# 27   False
# 28   False
# 29   False
# ..     ...
# 588  False
# 589  False
# 590  False
# 591  False
# 592  False
# 593  False
# 594  False
# 595  False
# 596  False
# 597  False
# 598  False
# 599  False
# 600  False
# 601  False
# 602  False
# 603  False
# 604  False
# 605  False
# 606  False
# 607  False
# 608  False
# 609  False
# 610  False
# 611  False
# 612  False
# 613  False
# 614  False
# 615  False
# 616  False
# 617   True
#
# [618 rows x 7 columns]

# %% [markdown]
# # gensim
# ## Phrase Modeling

# %%
# Phrase Modeling e.g., "Happy Hour"

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

# %%
#is_stop
def norm_lem():
    for doc in documents:
        parsed_doc = nlp(doc)
        for sent in parsed_doc.sents:
            yield u' '.join([token.lemma_ for token in sent if not token.is_punct and not token.is_space])

# %%
import codecs

# %%
with codecs.open("LineSentenceFile.txt", 'w', encoding='utf_8') as f:
    for s in norm_lem():
        f.write(s + "\n")

# %%
import itertools as it
for s in it.islice(LineSentence("LineSentenceFile.txt"),230,233):
    print u' '.join(s)

# %%
bigram_model = Phrases(LineSentence("LineSentenceFile.txt"))

# %%
bigram_model.save("BigramModel.txt")
with codecs.open("BigramSentenceFile.txt", 'w', encoding='utf_8') as f:
    for s in LineSentence("LineSentenceFile.txt"):
        f.write(u' '.join(bigram_model[s]) + "\n")

# %%
trigram_model = Phrases(LineSentence("BigramSentenceFile.txt"))

# %%
trigram_model.save("TrigramModel.txt")
with codecs.open("TrigramSentenceFile.txt", 'w', encoding='utf_8') as f:
    for s in LineSentence("BigramSentenceFile.txt"):
        f.write(u' '.join(trigram_model[s]) + "\n")

# %%
import itertools as it
for s in it.islice(LineSentence("TrigramSentenceFile.txt"),139,146):
    print u' '.join(s)
# Out:
# i_find_myself draw to a simple stovetop lamb stew call spezzatino di agnello season with only a pinch of saffron and a splash of wine then shower with lot_of chop mint
# fabrizia cut lamb shoulder into cube to make this but since my butcher have beautiful thick cut shoulder chop i decide to make mine with those
# once assemble this fragrant stew take only about an_hour to cook
# it have a bright flavored lightness that make it ideal for these still rather balmy september evening
# i serve it with plain boil potato nothing more be need
# while i will remember the summer of 2013 as the one i_do_not spend in sicily the meal i have be cook lately have have a distinctly sicilian accent
# this_year it seem the vacation be happen right in my_own kitchen

# %%
with codecs.open("Trigram_documents.txt", 'w', encoding='utf_8') as f:
    for doc in [d for d in documents if len(d) > 0]:
        parsed_doc = nlp(doc)
        tri = trigram_model[bigram_model[[token.lemma_ for token in parsed_doc if not token.is_punct and not token.is_space]]]         
        f.write(u' '.join([t for t in tri if t not in spacy.en.STOPWORDS])+'\n')

# %% [markdown]
# # gensim
# ## Topic Modeling

# %%
# topic modeling
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore

#pip install pyldavis
import pyLDAvis
import pyLDAvis.gensim
import warnings
#from cPickle import pickle

# %%
TrigramDictionary = Dictionary(LineSentence("Trigram_documents.txt"))
TrigramDictionary.filter_extremes(no_below=10, no_above=.4)
TrigramDictionary.filter_n_most_frequent(300)
TrigramDictionary.compactify()
#TrigramDictionary.save("TrigramDictionary.txt")
#TrigramDictionary = Dictionary.load("TrigramDictionary.txt")

# %%
def bow():
    for doc in LineSentence("Trigram_documents.txt"):
        yield TrigramDictionary.doc2bow(doc)

# %%
MmCorpus.serialize("Trigram_documents_bow.txt", bow())

# %%
lda = LdaMulticore(MmCorpus("Trigram_documents_bow.txt"), num_topics=6, workers=1, id2word=TrigramDictionary)

# %%
# explore topics
for term, freq in lda.show_topic(2,10):
    print term, ":", round(freq, 3)
# Out:
# music : 0.002
# film : 0.002
# vote : 0.002
# economy : 0.002
# syria : 0.002
# space : 0.002
# student : 0.002
# court : 0.001
# college : 0.001
# performance : 0.001

# %%
lda_vis = pyLDAvis.gensim.prepare(lda, MmCorpus("Trigram_documents_bow.txt"), TrigramDictionary)

# %%
pyLDAvis.display(lda_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1113076915683369770721655"></div>
# <script type="text/javascript">
#
# var ldavis_el1113076915683369770721655_data = {"plot.opts": {"xlab": "PC1", "ylab": "PC2"}, "topic.order": [2, 3, 6, 4, 1, 5], "token.table": {"Topic": [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1 ...

# %%
d = 2
print lda[list(bow())[d]]
print u' '.join(list(LineSentence("Trigram_documents.txt"))[d])
documents[d]
# Out:
# [(1, 0.9930990701312884)]
# shin star doctor_sleep stephen_king 's much-â­anticipated sequel shining hardcover list official release date sept._24 1977 shining spend time way cultural touchstone sell paperback especially stanley kubrick 's 1980 film adaptation shining king 's novel book_review daily new_york_times pay_attention king wish n't stephen_king elegant writer jack sullivan grouse book_review mildly daily 's reviewer richard r. lingeman kinder evil slapdash unfocused eventually preposterous write king natural lack control simply rear let fly fireball a_lot_of wild pitch result criticism apparently sting sale important king later tell lingeman want_to nominate national book award grow_up read king literary establishment gradually come 2003 national book foundation award medal distinguished contribution american letter ballad jail reading next_week 's issue lauren groff review peter orner 's new story collection car sagamore bridge orner hit best seller list despite critical acclaim recent brush wild popular fiction expert witness lawsuit involve california prisoner 's right read werewolf erotica plaintiff inmate pelican bay state prison successfully appeal copy mathilde madden 's silver crown confiscate stake case tricky subjective issue literary value orner tell_me e_mail fiction writer you_can_not ask read werewolf erotica especially good cause right read pretty_good cause orner end_up tear book he_say tend_to slow reader read silver crown fast prose let_'s i_wish_i as_much action my_own book orner study law work prison legal capacity write teacher he_' sympathetic tell_me challenge tend_to allow book correctional officer enforce discipline incredibly tough environment he_say pelican bay violent prison california extraordinarily problem humble thought speak writer inmate read book werewolf sex problem
# u'\n\n\n\n\n\n\n\n\n\n\n\'shining\' star: "doctor sleep," stephen king\'s much-\xe2\xadanticipated sequel to "the shining," isn\'t on the hardcover list yet - its official release date is sept. 24 - but back in 1977, "the shining" did spend time there on its way to becoming a cultural touchstone. (it also sold well in paperback, especially after stanley kubrick\'s 1980 film adaptation.)        \n \n\n"the shining" was king\'s third novel, and both the book review and the daily new york times paid attention, though king might have wished they hadn\'t: "to say that stephen king is not an elegant writer," jack sullivan groused in the book review, "is putting it mildly." the daily\'s reviewer, richard r. lingeman, wasn\'t much kinder: "the evil is slapdash, unfocused and eventually preposterous," he wrote. "king is a natural, but he lacks control; he simply rears back and lets fly with the fireball, and a lot of wild pitches result." the criticism apparently stung. "sales aren\'t all-important," king later told lingeman. "we all want to be nominated for a national book award." i grew up reading king, and the literary establishment has gradually come around; in 2003, the national book foundation awarded him a medal for distinguished contribution to american letters.        \nthe ballad of jail reading: in next week\'s issue, lauren groff will review peter orner\'s new story collection, "last car over the sagamore bridge." orner has never hit the best-seller list, despite critical acclaim, but he did have a recent brush with the wilder side of popular fiction - as the expert witness in a lawsuit involving a california prisoner\'s right to read werewolf erotica. (the plaintiff, an inmate at pelican bay state prison, successfully appealed after his copy of mathilde madden\'s "silver crown" was confiscated.)        \n"at stake in the case was the very tricky and very subjective issue of literary value," orner told me via e-mail. "as a fiction writer, you can\'t really say no when someone asks you to read some werewolf erotica, especially for a good cause. and i\'d say the right to read, wherever you are, is a pretty good cause." orner ended up "tearing through" the book, he said. "i tend to be a very slow reader. i read \'the silver crown\' fast - the prose really moves, let\'s say. i wish i had as much action in my own books."        \norner studied law, and has worked in prisons both in a legal capacity and as a writing teacher. he\'s sympathetic, he told me, to their challenges. but he would tend to allow most books. "correctional officers have to enforce discipline in an incredibly tough environment," he said. "pelican bay is one of the most violent prisons in california. . . . they\'ve got some extraordinarily serious problems. my humble thought, speaking as a writer, is that an inmate reading a book about werewolves having sex is the least of their problems."        \n\n\n\n \n\n\n\n'

# %% [markdown]
# # gensim
# ## Word2Vec

# %%
from gensim.models import Word2Vec

# %%
myW2V = Word2Vec(LineSentence("Trigram_documents.txt"), size=20, window=5, min_count=3, sg=1, seed=0)
for i in range(5):
    myW2V.train(LineSentence("Trigram_documents.txt"))

myW2V.init_sims()
myW2V.train_count
# Out:
# 6

# %%
sorted([(t, v.count) for t, v in myW2V.vocab.iteritems()], key = lambda x: -x[1])[:100]
# Out:
# [(u"'s", 4086),
#  (u'mr.', 1212),
#  (u'like', 1085),
#  (u'work', 917),
#  (u'new', 849),
#  (u'time', 780),
#  (u'people', 750),
#  (u'do_not', 655),
#  (u"it_'", 651),
#  (u'he_say', 647),
#  (u'there_be', 635),
#  (u'use', 628),
#  (u'year', 581),
#  (u'include', 564),
#  (u'$', 556),
#  (u'company', 534),
#  (u'come', 530),
#  (u'play', 526),
#  (u'state', 507),
#  (u'way', 492),
#  (u'game', 477),
#  (u'day', 453),
#  (u'start', 439),
#  (u'lead', 436),
#  (u'ms.', 417),
#  (u'run', 414),
#  (u'new_york', 411),
#  (u'end', 408),
#  (u'team', 407),
#  (u'government', 407),
#  (u'help', 394),
#  (u'man', 386),
#  (u'leave', 379),
#  (u'world', 377),
#  (u'million', 374),
#  (u'life', 372),
#  (u'woman', 371),
#  (u'high', 370),
#  (u'begin', 367),
#  (u'big', 363),
#  (u'long', 359),
#  (u'open', 358),
#  (u'city', 356),
#  (u'report', 356),
#  (u'home', 353),
#  (u'united_states', 352),
#  (u'group', 351),
#  (u'know', 347),
#  (u'write', 347),
#  (u'right', 344),
#  (u'plan', 344),
#  (u'thing', 344),
#  (u'american', 338),
#  (u'more_than', 334),
#  (u'country', 332),
#  (u'old', 332),
#  (u'change', 332),
#  (u'percent', 331),
#  (u'need', 323),
#  (u'win', 319),
#  (u'good', 319),
#  (u'house', 317),
#  (u'program', 312),
#  (u'child', 310),
#  (u'season', 308),
#  (u'street', 306),
#  (u'second', 303),
#  (u'book', 302),
#  (u'family', 299),
#  (u'official', 295),
#  (u'face', 294),
#  (u'look', 293),
#  (u'case', 292),
#  (u'party', 290),
#  (u'live', 288),
#  (u'center', 278),
#  (u'tell', 277),
#  (u'place', 276),
#  (u'issue', 275),
#  (u'president', 272),
#  (u'point', 271),
#  (u'think', 270),
#  (u'little', 269),
#  (u'law', 267),
#  (u'member', 267),
#  (u'great', 263),
#  (u'offer', 262),
#  (u'try_to', 259),
#  (u'public', 258),
#  (u'add', 255),
#  (u'allow', 254),
#  (u'line', 253),
#  (u'business', 253),
#  (u'pay', 253),
#  (u'job', 253),
#  (u'ask', 252),
#  (u'late', 252),
#  (u'hold', 251),
#  (u'accord_to', 249),
#  (u'bring', 247)]

# %%
# 1:16:42
# vectors

# %%
myW2V.most_similar(positive=['child'], topn=5)
# Out:
# [(u'his_mother', 0.8875871896743774),
#  (u'young_child', 0.8638801574707031),
#  (u'mother', 0.8543577194213867),
#  (u'parent', 0.8528305292129517),
#  (u'nurse', 0.8476693630218506)]

# %%
myW2V.most_similar(positive=[u'country'], topn=5)
# Out:
# [(u'plebiscite', 0.8763481974601746),
#  (u'europe', 0.8757608532905579),
#  (u'region', 0.8607292175292969),
#  (u'impoverished', 0.8591028451919556),
#  (u'united_states', 0.8570204973220825)]

# %%
# word algebra

# %%
myW2V.most_similar(positive=[u'united_states',u'middle_east'], negative=[u'democracy'], topn=1)
# Out:
# [(u'iran', 0.7919116020202637)]

# %%
myW2V.most_similar(positive=[u'united_states'], negative=[u'food'], topn=1)
# Out:
# [(u'france', 0.6525270342826843)]

# %%
myW2V.most_similar(positive=[u'food',u'russia'], topn=1)
# Out:
# [(u'burner', 0.8438848257064819)]

# %%
myW2V.most_similar(positive=[u'united_states',u'election'], topn=1)
# Out:
# [(u'troika', 0.8755705952644348)]

# %%
from sklearn.manifold import TSNE

# %%
ins = pd.DataFrame(myW2V.syn0, index=[t for t, v in myW2V.vocab.iteritems()]).drop(spacy.en.STOPWORDS, errors='ignore')
ins = ins[:1000]
tsne = TSNE()
tsne_vects = tsne.fit_transform(ins.values)
outs = pd.DataFrame(tsne_vects, index=pd.Index(ins.index), columns=['tsne_x','tsne_y'])
outs['word'] = outs.index

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="74dca3e8-0954-41be-bf59-41ca60f06c7a">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(outs)
tsne_plot = figure(title="tsne word encodings",
                   plot_width=800, plot_height=800,
                   tools=('pan, wheel_zoom, box_zoom, box_select, resize, reset'),
                   active_scroll='wheel_zoom')

tsne_plot.add_tools( HoverTool(tooltips = '@word') )
tsne_plot.circle('tsne_x','tsne_y', source=plot_data, color='blue', line_alpha=.2, fill_alpha=.1,
                 size=10, hover_line_color='black')

tsne_plot.title.text_font_size = value('16pt')
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None
show(tsne_plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="504561ed-93d2-44e6-8a27-11294143184d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("504561ed-93d2-44e6-8a27-11294143184d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '504561ed-93d2-44e6-8a27-11294143184d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3a9f944b-ee1f-4bce-b479-7c4e4ff024b1":{"roots":{"references":[{"attributes":{"below":[{"id":"ed8d92d6-9962-4425-8c16-d879413517cd","type":"LinearAxis"}],"left":[{"id":"d56b2707-2057-43b3-b129-0b04aa50b94c","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":800,"plot_width":800,"renderers":[{"id":"ed8d92d6-9962-4425-8c16-d879413517cd","type":"LinearAxis"},{"id":"073a8283-877e-471f-a759-1d4c7ed3d9e9","type":"Grid"},{"id":"d56b2707-2057-43b3-b129-0b04aa50b94c","type":"LinearAxis"},{"id":"3f091978-2ffd-4f27-9774-9114b748c203","type":"Grid"},{"id":"738aa08c-2b25-4dfa-a0e5-ca72d637693d","type":"BoxAnnotation"},{"id":"58a4d18d-9480-47aa-9984-c4bf230226b8","type":"BoxAnnotation"},{"id":"0661cd59-8345-412a-ac55-1b4ee0fe60da","type":"GlyphRenderer"}],"title":{"id":"7f4d16e8-09b9-4e3c-8d53-56c2cf158dbd","type":"Title"},"tool_events":{"id":"e3063344-891c-4f84-bc72-695773237776","type":"ToolEvents"},"toolbar":{"id":"feb20e02-cd8a-424d-afb0-131071e77060","type":"Toolbar"},"x_range":{"id":"e434df25-ade3-4b19-a147-152f54f69c07","type":"DataRange1d"},"y_range":{"id":"14341e52-c864-450e-8ebd-28e0bdeb3860","type":"DataRange1d"}},"id":"0988f195-bda0-42c1-947c-19f63f5ab2b4","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e3063344-891c-4f84-bc72-695773237776","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":{"id":"2f0de370-122f-41e6-b076-726440e8fb4f","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"c7f91129-f620-4477-a309-04b599180950","type":"PanTool"},{"id":"2f0de370-122f-41e6-b076-726440e8fb4f","type":"WheelZoomTool"},{"id":"c3e81ea7-4316-45ee-ae59-c8f10700d0ba","type":"BoxZoomTool"},{"id":"dcb7fab0-cf9f-4116-8b04-0c512cded60c","type":"BoxSelectTool"},{"id":"311f3749-14ce-49a5-aad9-9e19a55fc4bd","type":"ResizeTool"},{"id":"57c51ee2-dc1a-437e-9f2b-beaa3c4d78f9","type":"ResetTool"},{"id":"ff8258d1-9e63-40fa-bb37-e7312829c30d","type":"HoverTool"}]},"id":"feb20e02-cd8a-424d-afb0-131071e77060","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"tsne_x"},"y":{"field":"tsne_y"}},"id":"b6ec7db2-d687-4a51-ae3c-f82b0ff2c58d","type":"Circle"},{"attributes":{},"id":"376fe0b0-3eb1-4e9e-a968-d2af1f5df1cf","type":"BasicTicker"},{"attributes":{"plot":null,"text":"tsne word encodings","text_font_size":{"value":"16pt"}},"id":"7f4d16e8-09b9-4e3c-8d53-56c2cf158dbd","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"58a4d18d-9480-47aa-9984-c4bf230226b8","type":"BoxAnnotation"},{"attributes":{"callback":null,"plot":{"id":"0988f195-bda0-42c1-947c-19f63f5ab2b4","subtype":"Figure","type":"Plot"},"tooltips":"@word"},"id":"ff8258d1-9e63-40fa-bb37-e7312829c30d","type":"HoverTool"},{"attributes":{"formatter":{"id":"49dd5931-25aa-459c-b89d-711db016cd0b","type":"BasicTickFormatter"},"plot":{"id":"0988f195-bda0-42c1-947c-19f63f5ab2b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"376fe0b0-3eb1-4e9e-a968-d2af1f5df1cf","type":"BasicTicker"},"visible":false},"id":"d56b2707-2057-43b3-b129-0b04aa50b94c","type":"LinearAxis"},{"attributes":{"plot":{"id":"0988f195-bda0-42c1-947c-19f63f5ab2b4","subtype":"Figure","type":"Plot"}},"id":"311f3749-14ce-49a5-aad9-9e19a55fc4bd","type":"ResizeTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"tsne_x"},"y":{"field":"tsne_y"}},"id":"1f69e7f1-f9d4-47a1-9081-be0f2cd90f76","type":"Circle"},{"attributes":{"callback":null},"id":"14341e52-c864-450e-8ebd-28e0bdeb3860","type":"DataRange1d"},{"attributes":{"plot":{"id":"0988f195-bda0-42c1-947c-19f63f5ab2b4","subtype":" ...
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:52: DeprecationWarning: Comm._comm_id_default is deprecated: use @default decorator instead.
#   def _comm_id_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:29: DeprecationWarning: Comm._iopub_socket_default is deprecated: use @default decorator instead.
#   def _iopub_socket_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:24: DeprecationWarning: Comm._kernel_default is deprecated: use @default decorator instead.
#   def _kernel_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:32: DeprecationWarning: Comm._session_default is deprecated: use @default decorator instead.
#   def _session_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:41: DeprecationWarning: Comm._topic_default is deprecated: use @default decorator instead.
#   def _topic_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:24: DeprecationWarning: Comm._kernel_default is deprecated: use @default decorator instead.
#   def _kernel_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:52: DeprecationWarning: Comm._comm_id_default is deprecated: use @default decorator instead.
#   def _comm_id_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/manager.py:37: DeprecationWarning: CommManager._iopub_socket_default is deprecated: use @default decorator instead.
#   def _iopub_socket_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:32: DeprecationWarning: Comm._session_default is deprecated: use @default decorator instead.
#   def _session_default(self):
# /Users/schwarls37/anaconda/lib/python2.7/site-packages/ipykernel/comm/comm.py:41: DeprecationWarning: Comm._topic_default is deprecated: use @default decorator instead.
#   def _topic_default(self):
# <p><code>&lt;Bokeh Notebook handle for <strong>In[83]</strong>&gt;</code></p>

# %% [markdown]
# <img src="stuff/bayes.tiff",width=1000px, align='left'>

# %% [markdown]
# # OBJECTIVES:
# # 1. NB4NLP (Naive Bayes for Natural Language Processing)
# <br>
# # Bonus:
#
# # 1. Generative Modeling
# # 2. Why NB4NLP?
# # $\quad$ a. p>>n covariance matrix estimation
# # $\quad$ b. Computation

# %% [markdown]
# # NB4NLP
#
# # $
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# & \text{token 1} &  \text{token 2} & \cdots &\text{token p}& \textbf{Class Label } (Y) \\ \hline
# \text{document 1} &&&& &\\ \hline
# \text{document 2} &&&& &\\ \hline
# \vdots &&&& &\\ \hline
# \text{document n} &&&& &\\ \hline
# \end{array}
# $
#
#
# # $$
# \begin{align*}
# \textbf{X}_0 &= \text{"$\textbf{X}_0$ is a 'document' that..."} \\
# &= (t_1, t_2, \cdots, t_K)\\
# &\\
# Pr(Y_0=y_0|\textbf{X}_0) &= \frac{Pr(\textbf{X}_0|Y_0=y_0)Pr(Y_0=y_0)}{Pr(\textbf{X}_0)}\\
# &\propto  Pr(\textbf{X}_0|Y_0=y_0)Pr(Y_0=y_0)\\
# {}&\\
# Pr(Y_0=y_0) &= \sum_{i: Y_i=y_0}\frac{1}{n}\\
# Pr(\textbf{X}_0|Y_0=y_0) &= \prod_{k=1}^{|\textbf{X}_0|}Pr(X_{0k}|Y_0=y_0) \\
# &= \prod_{k=1}^{|\textbf{X}_0|} \left( \sum_{ \underset{\text{token}_{j}=X_{0k}}{\overset{i,j: Y_i=y_0}{}} }TF_{ij} \right)/\left( \sum_{ \underset{\;}{\overset{i,j: Y_i=y_0}{}} }TF_{ij} \right)
# \end{align*}
# $$
# # What is the assumption here?

# %% [markdown]
# # What if $TF_{ij}$ = 0?
# # Laplace Smoothing:
# # $$ \prod_{k=1}^{|\textbf{X}_0|} \left( \sum_{ \underset{\text{token}_{j}=X_{0k}}{\overset{i,j: Y_i=y_0}{}} }(TF_{ij}+\alpha) \right)/\left( \sum_{ \underset{\;}{\overset{i,j: Y_i=y_0}{}} }(TF_{ij} +\alpha) \right) $$

# %% [markdown]
# # How do we get rid of the *"proportional to"*?
# # $$
# \begin{align*}
# Pr(Y_0=y_0|\textbf{X}_0) &= \frac{Pr(\textbf{X}_0|Y_0=y_0)Pr(Y_0=y_0)}{\underset{y}{\sum} Pr(\textbf{X}_0|Y_0=y)Pr(Y_0=y)}\\
# &= \frac{\left(\prod_{k=1}^{|\textbf{X}_0|} p_k^{y_0}\right)Pr(Y_0=y_0)}{\underset{y}{\sum} \left(\prod_{k=1}^{|\textbf{X}_0|} p_k^y\right)Pr(Y_0=y)}
# \end{align*}$$
#
#
# # What about multiplying so many small probabilities together?
# # $$ \log\left(\prod_{k=1}^{|\textbf{X}_0|} p_k\right) = \sum_{k=1}^{|\textbf{X}_0|}  \log p_k $$
#
# # $$
# \begin{align*}
# Pr(Y_0=y_0|\textbf{X}_0) &= \frac{\exp\left(\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y_0} \right) Pr(Y_0=y_0)}{\underset{y}{\sum} \exp\left(\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y} \right) Pr(Y_0=y)}
# \end{align*}$$
#
# # Okay but this is still a really small number that we probably can't represent...
# # $$ Pr(\textbf{X}_0|Y_0=y) = \exp\left(\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^y \right) $$
#
# # But we can scale it!
# # $$
# \begin{align*}
# Pr(Y_0=y_0|\textbf{X}_0) &= \frac{\exp(C) \exp\left(\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y_0} \right) Pr(Y_0=y_0)}{\underset{y}{\sum}\exp(C) \exp\left(\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y} \right) Pr(Y_0=y)}\\
# &= \frac{exp\left(C+\sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y_0} \right) Pr(Y_0=y_0)}{\underset{y}{\sum}  \exp\left(C+ \sum_{k=1}^{|\textbf{X}_0|}  \log p_k^{y} \right) Pr(Y_0=y)}
# \end{align*}$$

# %% [markdown]
# # Discriminitive or Predictive (Conditional) Model:
# # $$ f(Y_0|\textbf{X}_0)$$
#
# # Generative (Joint) Model
# # $$ f(\textbf{X}_i,Y_i) \quad \sim \quad f(\textbf{X}_i|Y_i) $$

# %% [markdown]
# # NB4NLP
# # $$
# \begin{align*}
# Pr(\textbf{X}_i^*|Y_i=y) &= Multinomial(\hat \pi_y)\\
#  &= f_{\hat \pi_y}(\textbf{X}_i^*)\\
# Pr(Y_i=y) &= \hat w_y\\
# Pr(\textbf{X}_i^*,Y_i) &= \sum_y \hat w_y f_{\hat \pi_y}(\textbf{X}_i^*) \\
# \end{align*}$$

# %% [markdown]
# # $$
# \begin{align*}
# \textbf{X}_0 &= \text{"$\textbf{X}_0$ is a 'document' that..."} \\
# &= (t_1, t_2, \cdots, t_K)\\
# \textbf{X}_0^* &= (TF_{01}^*, TF_{02}^*, \cdots, TF_{0p}^*)\\
# {}\\
# \textbf{X}_i &= (X_{i1}, X_{i2}, \cdots, X_{ip})\\
# \end{align*}$$

# %% [markdown]
# # NB4continuousfeatures
# # $$
# \begin{align*}
# Pr(\textbf{X}|Y=y) &= MVN(\hat \mu_y, \hat \Sigma_y)\\
#  &= f_{\hat \mu_y, \hat \Sigma_y}(\textbf{X})\\
# Pr(Y=y) &= \hat w_y\\
# Pr(\textbf{X},Y=y) &= \sum_y \hat w_y f_{\hat \mu_y, \hat \Sigma_y}(\textbf{X})
# \end{align*}$$

# %% [markdown]
# <img src="stuff/mixture.png",width=500px, align='center'>

# %% [markdown]
# # $$
# \left[\begin{array}{cccc}
# X_{11}&X_{12} & \cdots & X_{1p} \\
# X_{21}&X_{22} & \cdots & X_{2p} \\
# \vdots &\vdots &\ddots&\vdots \\\hline
# X_{i1}&X_{i2} & \cdots & X_{ip} \\ \hline
# \vdots &\vdots &\ddots&\vdots \\
# X_{n1}&X_{n2} & \cdots & X_{np} \\
# \end{array}\right]
# $$
#
# # $$ {\boldsymbol X}_i = (X_{i1}, X_{i2}, \cdots, X_{ip})^T \sim MVN({\boldsymbol \mu}_p,\Sigma_{p \times p})$$
#
#
# # $${\boldsymbol X}_i = \left(\begin{array}{c} {X_{i1}} \\ {X_{i2}} \\ \vdots\\ {X_{ip}} \end{array} \right) \sim MVN\left(
#  \left[\begin{array}{c} \mu_{{X_{i1}}} \\ \mu_{{X_{i2}}} \\ \vdots\\ \mu_{{X_{ip}}} \end{array} \right]_,
# \left[\begin{array}{cccc}\sigma^2_{{X_{i1}}}&\sigma_{{X_{i1}X_{i2}}} & \cdots & \sigma_{{X_{i1}X_{ip}}}\\
# \sigma_{{X_{i2}X_{i1}}} &\sigma^2_{{X_{i2}}}&  \cdots & \sigma_{{X_{i2}X_{ip}}}\\
# \vdots &\vdots&  \ddots & \vdots\\
# \sigma_{{X_{ip}X_{i1}}} & \sigma_{{X_{ip}X_{i2}}} &   \cdots & \sigma^2_{{X_{ip}}}\\ \end{array}\right]\right)$$
#
# # Can't estimate the covariance matrix above when $p>n$... so instead we'll use:
#
# # $${\boldsymbol X}_i = \left(\begin{array}{c} {X_{i1}} \\ {X_{i2}} \\ \vdots\\ {X_{ip}} \end{array} \right) \sim MVN\left(
#  \left[\begin{array}{c} \mu_{{X_{i1}}} \\ \mu_{{X_{i2}}} \\ \vdots\\ \mu_{{X_{ip}}} \end{array} \right]_,
# \left[\begin{array}{cccc}\sigma^2_{{X_1}}&\;\;\;0\;\;\;& \cdots & \;\;\;0\;\;\;\\
# 0&\sigma^2_{{X_2}}&  \cdots & 0\\
# \vdots &\vdots&  \ddots & \vdots\\
# \;\;\;\;0\;\;\;\; & 0 &   \cdots & \sigma^2_{{X_p}}  \\ \end{array}\right]\right)$$

# %% [markdown]
# <img src="stuff/nb.tiff",width=1000px, align='center'>

# %% [markdown]
# <table>
# <tr>
# <td><img src="stuff/mix2b.png",width=600px, align='center'></td>
# <td><img src="stuff/mix2.png",width=600px, align='center'></td>
# </table>

# %% [markdown]
# # Highly correlated features will ruin classification
# # Probability estimates are not particularly reliable
# # Less naive methodologies will outperform NB
# # But NB is FAST and can give acceptable results
# # Especially in HUGE data sets where it's the only way

# %%
# Austin: NLP
# 
# onsite info collected

# Noah: Product Hunt
